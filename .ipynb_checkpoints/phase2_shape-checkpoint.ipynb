# %%
import pandas as pd

# %%
TARGET_COLUMNS = [
    "year",
    "constituency",
    "candidate",
    "party",
    "votes",
    "total_votes",
    "position"
]

# %%
df = pd.read_csv("raw_data/2021.csv")
df.head()
