# %%
import pandas as pd

# Step 0: Load CSV without header
df = pd.read_csv("raw_2021.csv", header=None)

# Step 1: Find the header row automatically
# We look for the row that contains "STATE/UT NAME" (case-insensitive)
header_row_index = df[df.apply(lambda row: row.astype(str).str.contains("STATE/UT NAME", case=False).any(), axis=1)].index[0]

# Step 2: Promote that row as header
df.columns = df.iloc[header_row_index]
df = df[header_row_index + 1:].reset_index(drop=True)

# Step 3: Drop any fully empty rows
df = df.dropna(how="all")

# Step 4: Normalize column names
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace("/", "_", regex=False)
      .str.replace(".", "", regex=False)
      .str.replace("%", "pct", regex=False)
      .str.replace(" ", "_", regex=False)
)

# Step 5: Strip and uppercase key text columns
for col in ["state_ut_name", "ac_name", "candidate_name"]:
    df[col] = df[col].str.upper().str.strip()

# Step 6: Convert numeric columns to proper types
numeric_cols = ["age", "general", "postal", "total", "pct_votes_polled", "total_electors"]
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# Step 7: Split candidate_name into candidate_no and candidate_name_clean
df[['candidate_no', 'candidate_name_clean']] = df['candidate_name'].str.extract(r'(\d+)\s+(.*)')

# Optional: drop original candidate_name and rename
df = df.drop(columns=['candidate_name'])
df = df.rename(columns={'candidate_name_clean': 'candidate_name'})

# Step 8: Final check
print(df.head())
print(df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 4
#       1 import pandas as pd
#       3 # Step 0: Load CSV without header
# ----> 4 df = pd.read_csv("raw_data/2021.csv", header=None)
#       6 # Step 1: Find the header row automatically
#       7 # We look for the row that contains "STATE/UT NAME" (case-insensitive)
#       8 header_row_index = df[df.apply(lambda row: row.astype(str).str.contains("STATE/UT NAME", case=False).any(), axis=1)].index[0]
#
# ...
